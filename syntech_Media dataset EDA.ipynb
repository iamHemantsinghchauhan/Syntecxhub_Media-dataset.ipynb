# %%
# Netflix / Media Dataset EDA Project

## Project Title

Movie Dataset Exploratory Data Analysis (EDA)

---

# Objective

The goal of this project is to analyze a movie/media dataset using Python libraries like Pandas, Matplotlib, and Seaborn.

This project includes:

* Data Cleaning
* Data Analysis
* Data Visualization
* Trend Analysis
* Genre Analysis
* Popularity Analysis
* Top Rated Movies
* Exporting Cleaned Data

---

# Dataset Information

Dataset Name: `mymoviedb.csv`

## Columns Present

* Release_Date
* Title
* Overview
* Popularity
* Vote_Count
* Vote_Average
* Original_Language
* Genre
* Poster_Url

Total Rows: 9837

---

# Libraries Required

---

# Complete Jupyter Notebook Code

```python
# =====================================
# MOVIE DATASET EDA PROJECT
# =====================================

# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

x

print('Dataset Loaded Successfully!')

# =====================================
# BASIC INFORMATION
# =====================================

print('\nFirst 5 Rows')
print(df.head())

print('\nDataset Shape')
print(df.shape)

print('\nColumns')
print(df.columns)

print('\nMissing Values')
print(df.isnull().sum())

print('\nDataset Information')
print(df.info())

# =====================================
# DATA CLEANING
# =====================================

# Remove duplicates

df.drop_duplicates(inplace=True)

# Convert release date to datetime

df['Release_Date'] = pd.to_datetime(df['Release_Date'])

# Create Release Year Column

df['Release_Year'] = df['Release_Date'].dt.year

print('\nData Cleaning Completed!')

# =====================================
# SUMMARY STATISTICS
# =====================================

print('\nSummary Statistics')
print(df.describe())

# =====================================
# TOP 10 MOST POPULAR MOVIES
# =====================================

popular_movies = df[['Title', 'Popularity']].sort_values(
    by='Popularity',
    ascending=False
).head(10)

print('\nTop 10 Popular Movies')
print(popular_movies)

# =====================================
# VISUALIZATION - TOP POPULAR MOVIES
# =====================================

plt.figure(figsize=(12,6))

sns.barplot(
    x='Popularity',
    y='Title',
    data=popular_movies
)

plt.title('Top 10 Most Popular Movies')
plt.xlabel('Popularity Score')
plt.ylabel('Movie Title')

plt.show()

# =====================================
# TOP RATED MOVIES
# =====================================

rated_movies = df[['Title', 'Vote_Average']].sort_values(
    by='Vote_Average',
    ascending=False
).head(10)

print('\nTop Rated Movies')
print(rated_movies)

# =====================================
# VISUALIZATION - TOP RATED MOVIES
# =====================================

plt.figure(figsize=(12,6))

sns.barplot(
    x='Vote_Average',
    y='Title',
    data=rated_movies
)

plt.title('Top Rated Movies')
plt.xlabel('Average Rating')
plt.ylabel('Movie Title')

plt.show()

# =====================================
# MOVIE RELEASE TREND
# =====================================

plt.figure(figsize=(14,6))

release_trend = df['Release_Year'].value_counts().sort_index()

release_trend.plot()

plt.title('Movies Released Over Years')
plt.xlabel('Year')
plt.ylabel('Number of Movies')

plt.show()

# =====================================
# LANGUAGE ANALYSIS
# =====================================

language_count = df['Original_Language'].value_counts().head(10)

plt.figure(figsize=(12,6))

sns.barplot(
    x=language_count.index,
    y=language_count.values
)

plt.title('Top 10 Languages in Dataset')
plt.xlabel('Language')
plt.ylabel('Movie Count')

plt.show()

# =====================================
# GENRE ANALYSIS
# =====================================

# Split genres
all_genres = df['Genre'].str.split(', ', expand=True).stack()

# Count genres
genre_count = all_genres.value_counts().head(10)

print('\nTop Genres')
print(genre_count)

# Visualization

plt.figure(figsize=(12,6))

sns.barplot(
    x=genre_count.values,
    y=genre_count.index
)

plt.title('Top 10 Genres')
plt.xlabel('Count')
plt.ylabel('Genre')

plt.show()

# =====================================
# POPULARITY DISTRIBUTION
# =====================================

plt.figure(figsize=(12,6))

sns.histplot(df['Popularity'], bins=30)

plt.title('Popularity Distribution')
plt.xlabel('Popularity')

plt.show()

# =====================================
# VOTE DISTRIBUTION
# =====================================

plt.figure(figsize=(12,6))

sns.histplot(df['Vote_Average'], bins=20)

plt.title('Vote Average Distribution')
plt.xlabel('Vote Average')

plt.show()

# =====================================
# MOST VOTED MOVIES
# =====================================

most_voted = df[['Title', 'Vote_Count']].sort_values(
    by='Vote_Count',
    ascending=False
).head(10)

print('\nMost Voted Movies')
print(most_voted)

# Visualization

plt.figure(figsize=(12,6))

sns.barplot(
    x='Vote_Count',
    y='Title',
    data=most_voted
)

plt.title('Top 10 Most Voted Movies')
plt.xlabel('Vote Count')

plt.show()

# =====================================
# EXPORT CLEANED DATA
# =====================================

# Save cleaned dataset

df.to_csv('cleaned_movie_dataset.csv', index=False)

print('\nCleaned Dataset Exported Successfully!')

# =====================================
# PROJECT SUMMARY
# =====================================

print('\n===== PROJECT SUMMARY =====')

print(f'Total Movies: {len(df)}')
print(f'Total Languages: {df["Original_Language"].nunique()}')
print(f'Total Genres: {all_genres.nunique()}')

print('\nEDA Project Completed Successfully!')
```

---

# Expected Insights

After completing this project, you can explain:

* Which movies are most popular
* Which genres dominate the dataset
* Release trends over years
* Most common languages
* Rating distribution of movies
* Most voted movies

---

# Project Folder Structure

```bash
Movie-EDA-Project/
│
├── mymoviedb.csv
├── cleaned_movie_dataset.csv
├── movie_eda.ipynb
├── README.md
└── requirements.txt
```

---

# requirements.txt

```txt
pandas
numpy
matplotlib
seaborn
```

---

# Best README Description

## Movie Dataset Exploratory Data Analysis

This project performs Exploratory Data Analysis (EDA) on a movie/media dataset using Python.

### Features

* Data Cleaning
* Trend Analysis
* Genre Analysis
* Popularity Analysis
* Ratings Analysis
* Data Visualization

### Technologies Used

* Python
* Pandas
* NumPy
* Matplotlib
* Seaborn

### Key Insights

* Identified top-rated movies
* Analyzed popularity distribution
* Found most common genres
* Studied movie release trends over time
* Compared language distributions

---

# Best Project Explanation for Interview

“In this project, I performed Exploratory Data Analysis on a movie dataset using Pandas, Matplotlib, and Seaborn. I cleaned the data, analyzed popularity, ratings, genres, and release trends, and created visualizations to generate meaningful insights from the dataset.”

---

# Important Interview Questions

## 1. What is EDA?

EDA stands for Exploratory Data Analysis used to understand patterns and insights in data.

## 2. Why use Pandas?

Pandas helps in data manipulation and analysis.

## 3. Why use Seaborn and Matplotlib?

They help create visualizations and graphs.

## 4. What is data cleaning?

Handling missing values, duplicates, and incorrect data.

## 5. What insights did you find?

* Most popular movies
* Top genres
* Movie trends by year
* Most common languages
# Out:
#   Cell In[3], line 339
#     │
#     ^
# SyntaxError: invalid character '│' (U+2502)

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv(
    "C:/Users/iamhe/Downloads/mymoviedb.csv",
    engine="python"
)

print(df.head())
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
print(df.isnull().sum())
# Out:
# Release_Date          0
# Title                 9
# Overview              9
# Popularity           10
# Vote_Count           10
# Vote_Average         10
# Original_Language    10
# Genre                11
# Poster_Url           11
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

print("Duplicates Removed!")
# Out:
# Duplicates Removed!

# %%
df['Release_Date'] = pd.to_datetime(
    df['Release_Date'],
    errors='coerce'
)

# %%
df['Release_Year'] = df['Release_Date'].dt.year

# %%
print(df.describe())
# Out:
#                         Release_Date   Popularity  Release_Year
# count                           9827  9827.000000   9827.000000
# mean   2006-09-23 11:05:51.317797888    40.320570   2006.203623
# min              1902-04-17 00:00:00     7.100000   1902.000000
# 25%              2000-10-18 00:00:00    16.127500   2000.000000
# 50%              2011-09-13 00:00:00    21.191000   2011.000000
# 75%              2017-11-22 00:00:00    35.174500   2017.000000
# max              2024-07-03 00:00:00  5083.954000   2024.000000
# std                              NaN   108.874308     15.685554

# %%
popular_movies = df[['Title', 'Popularity']].sort_values(
    by='Popularity',
    ascending=False
).head(10)

print(popular_movies)
# Out:
#                      Title  Popularity
# 0  Spider-Man: No Way Home    5083.954
# 1               The Batman    3827.658
# 2                  No Exit    2618.087
# 3                  Encanto    2402.201
# 4           The King's Man    1895.511
# 5             The Commando    1750.484
# 6                   Scream    1675.161
# 7                     Kimi    1601.782
# 8     Fistful of Vengeance    1594.013
# 9                 Eternals    1537.406

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x='Popularity',
    y='Title',
    data=popular_movies
)

plt.title('Top 10 Most Popular Movies')
plt.xlabel('Popularity Score')
plt.ylabel('Movie Title')

plt.show()

# %%
rated_movies = df[['Title', 'Vote_Average']].sort_values(
    by='Vote_Average',
    ascending=False
).head(10)

print(rated_movies)
# Out:
#                                               Title Vote_Average
# 1115                                         61.328    Animation
# 7349              Franco Escamilla: Por La Anécdota          9.2
# 2335                              Impossible Things          9.1
# 667   Demon Slayer: Kimetsu no Yaiba Sibling's Bond          9.1
# 2401          The Three Deaths of Marisela Escobedo          9.0
# 7411                                    My Sex Doll          9.0
# 6738                                  Mission «Sky»          9.0
# 7024                    Sex School: Dorms of Desire          9.0
# 8657                      Burn the Stage: The Movie          8.9
# 5079                                Ni tuyo, Ni mía          8.9

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x='Vote_Average',
    y='Title',
    data=rated_movies
)

plt.title('Top Rated Movies')
plt.xlabel('Average Rating')
plt.ylabel('Movie Title')

plt.show()

# %%
plt.figure(figsize=(14,6))

release_trend = df['Release_Year'].value_counts().sort_index()

release_trend.plot()

plt.title('Movies Released Over Years')
plt.xlabel('Year')
plt.ylabel('Number of Movies')

plt.show()

# %%
language_count = df['Original_Language'].value_counts().head(10)

print(language_count)
# Out:
# Original_Language
# en    7569
# ja     645
# es     339
# fr     292
# ko     170
# zh     129
# it     123
# cn     109
# ru      83
# de      82
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x=language_count.index,
    y=language_count.values
)

plt.title('Top 10 Languages')
plt.xlabel('Language')
plt.ylabel('Movie Count')

plt.show()

# %%
all_genres = df['Genre'].str.split(', ', expand=True).stack()

genre_count = all_genres.value_counts().head(10)

print(genre_count)
# Out:
# Drama        3744
# Comedy       3031
# Action       2686
# Thriller     2488
# Adventure    1853
# Romance      1476
# Horror       1470
# Animation    1438
# Family       1414
# Fantasy      1308
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x=genre_count.values,
    y=genre_count.index
)

plt.title('Top 10 Genres')
plt.xlabel('Count')
plt.ylabel('Genre')

plt.show()

# %%
most_voted = df[['Title', 'Vote_Count']].sort_values(
    by='Vote_Count',
    ascending=False
).head(10)

print(most_voted)
# Out:
#                           Title Vote_Count
# 1115                     61.328         en
# 6231  Elizabeth: The Golden Age        999
# 1672                      Greta        999
# 389        John Wick: Chapter 2       9982
# 8459             Broken Flowers        998
# 5462                     Takers        998
# 1703              So Undercover        997
# 4539                 Second Act        997
# 1340                   Kick-Ass       9966
# 158    Boruto: Naruto the Movie        996

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x='Vote_Count',
    y='Title',
    data=most_voted
)

plt.title('Top 10 Most Voted Movies')
plt.xlabel('Vote Count')

plt.show()

# %%
print("===== PROJECT SUMMARY =====")

print(f"Total Movies: {len(df)}")

print(f"Total Languages: {df['Original_Language'].nunique()}")

print(f"Total Genres: {all_genres.nunique()}")

print("EDA Project Completed Successfully!")
# Out:
# ===== PROJECT SUMMARY =====
# Total Movies: 9837
# Total Languages: 44
# Total Genres: 19
# EDA Project Completed Successfully!
